# %% [markdown]
# ## Image Classification for a City Dog Show
#
# ![image.png](attachment:44d5ee1d-e3b9-4bb5-9e6d-7cf4b1d148c9.png)

# %%
pwd
# Out:
# '/Users/mekalathuruchenchaiah/Desktop/PROGRAMMING/Udacity Nanodegrees/Data Science with Python'

# %%
from os import listdir

dir ='/Users/mekalathuruchenchaiah/Desktop/PROGRAMMING/Udacity Nanodegrees/Data Science with Python'
filenames = listdir(dir)
filenames
# Out:
# ['15_Statistics.ipynb',
#  '09_Matplotlib_and_Seaborn_Part_2.ipynb',
#  '08_Pandas_Part_A.ipynb',
#  '06_Object_Oriented_programming_Part_B.ipynb',
#  '04_Functions.ipynb',
#  '00_All_Topics_Practice.ipynb',
#  '02_Control_Flow.ipynb',
#  '09_Matplotlib_and_Seaborn_Part_1.ipynb',
#  '07_Advanced_Topics.ipynb',
#  '08_Pandas_Part_B.ipynb',
#  '12_Calculus_A.ipynb',
#  '01_Data_Types_Operators.ipynb',
#  '16_Explore_Us_Bike_Share_data.ipynb',
#  '001_Introduction_to_SQL.ipynb',
#  '11_Linear_Algebra_A_Vectors.ipynb',
#  '07_Numpy_Part_A.ipynb',
#  '06_Object_Oriented_programming_Part_A-Copy1.ipynb',
#  'files',
#  '05_Scripting.ipynb',
#  '.ipynb_checkpoints',
#  '.git',
#  'useful_functions.py',
#  '02_Data_Structures.ipynb',
#  '10_Image_Classifier_Using_PreTrained_Part_A.ipynb',
#  '07_Numpy_Part_B.ipynb']
